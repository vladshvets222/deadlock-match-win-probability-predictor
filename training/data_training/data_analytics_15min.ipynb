# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("YOUR_PATH_HERE")

print(df.head())

print(df.shape)

print(df.info())
# Out:
#    match_id  team0_won  team0_team_total_kills  team0_team_total_deaths  \
# 0   1883785          0                       2                       38
# 1   1741000          1                      21                        6
# 2   1894783          1                      28                       16
# 3  30579330          0                      26                       14
# 4  38984295          1                      34                        7
#
#    team0_team_total_networth  team0_team_total_damage  \
# 0                      42306                    27286
# 1                      65537                    44084
# 2                      78476                    41284
# 3                      71140                    41232
# 4                      78151                    69357
#
#    team0_team_total_objectivedamage  team0_team_avg_level  \
# 0                              4419              9.166667
# 1                             14300             12.000000
# 2                             18389             13.666667
# 3                              8697             16.833333
# 4                             15038             16.166667
#
#    team0_team_gold_per_minute  team0_p1_hero  ...  team1_p6_assists  \
# 0                  470.066635              4  ...                 4
# 1                  728.188840              2  ...                 0
# 2                  871.955497              2  ...                 2
# 3                  790.444392              3  ...                 2
# 4                  868.344387              3  ...                 0
#
#    team1_p6_networth  team1_p6_damage  team1_p6_creeps  team1_p6_level  \
# 0              10980             3245               55              12
# 1               5860             4451               51               8
# 2               7977             2214               35              10
# 3               8815             5786               43              13
# 4               7924             1733               29              12
#
#    team1_p6_objective_damage  team1_p6_denies  team1_p6_gold_per_minute  \
# 0                       5247               13                731.999951
# 1                       2097                0                390.666641
# 2                       2887                6                531.799965
# 3                       1748                4                587.666627
# 4                        782                0                528.266631
#
#    team1_p6_player_healing  team1_p6_self_healing
# 0                     2672                   1911
# 1                        0                      0
# 2                        0                      0
# 3                      651                    651
# 4                      867                    867
#
# [5 rows x 184 columns]
# (18393, 184)
# <class 'pandas.DataFrame'>
# RangeIndex: 18393 entries, 0 to 18392
# Columns: 184 entries, match_id to team1_p6_self_healing
# dtypes: float64(16), int64(168)
# memory usage: 25.8 MB
# None

# %% [markdown]
# # Inspecting Missing Values and Data/Features Distributions

# %%
missing = df.isnull().sum()

missing = missing[missing > 0]

print(missing)
# Out:
# Series([], dtype: int64)

# %%
print(df["team0_won"].value_counts())

print(df["team0_won"].value_counts(normalize=True))
# Out:
# team0_won
# 1    9253
# 0    9140
# Name: count, dtype: int64
# team0_won
# 1    0.503072
# 0    0.496928
# Name: proportion, dtype: float64

# %%
df.hist(figsize=(40, 40))

plt.show()

# %% [markdown]
# # Removing Outliers

# %%
feature = "team0_team_total_networth"

print(df[feature].describe())

df[feature].hist(bins=50)

plt.title(feature)

plt.xlabel(feature)

plt.ylabel("Count")

plt.show()
# Out:
# count     18393.000000
# mean      75187.746806
# std        7108.716690
# min       11498.000000
# 25%       70502.000000
# 50%       74928.000000
# 75%       79564.000000
# max      113983.000000
# Name: team0_team_total_networth, dtype: float64

# %%
threshold = 40000

count = (df["team0_team_total_networth"] < threshold).sum()

print(count)

outliers = df[df["team0_team_total_networth"] < 40000]

print((outliers.head(20)))
# Out:
# 12
#        match_id  team0_won  team0_team_total_kills  team0_team_total_deaths  \
# 4465   82138156          0                       6                        8
# 5204   82356913          0                       6                       10
# 6311   82537096          0                       4                        9
# 6727   82568884          0                       7                       16
# 7218   82584606          0                       9                        8
# 7695   82619103          0                       2                        1
# 9783   82740729          0                       6                        6
# 9968   82742774          0                       3                        9
# 11230  82777677          0                       1                        3
# 15275  83148720          0                       6                        5
# 17402  83233454          0                       8                        7
# 17571  83239773          0                       4                        5
#
#        team0_team_total_networth  team0_team_total_damage  \
# 4465                       28655                    19378
# 5204                       36065                    19075
# 6311                       36748                    15774
# 6727                       35156                    20232
# 7218                       35094                    12809
# 7695                       29782                     5875
# 9783                       35029                    22536
# 9968                       34508                    13593
# 11230                      11498                     2666
# 15275                      37657                    24582
# 17402                      23186                    13674
# 17571                      28362                    13082
#
#        team0_team_total_objectivedamage  team0_team_avg_level  \
# 4465                               5202              7.333333
# 5204                               4362              9.000000
# 6311                               2869              8.333333
# 6727                               2806              8.666667
# 7218                               4386              6.666667
# 7695                               6419              4.500000
# 9783                               9028              9.166667
# 9968                               7654              7.666667
# 11230                                 0              3.166667
# 15275                              6561              9.666667
# 17402                              2721              6.833333
# 17571                              3369              6.333333
#
#        team0_team_gold_per_minute  team0_p1_hero  ...  team1_p6_assists  \
# 4465                   318.388868             64  ...                 0
# 5204                   415.974596             80  ...                 0
# 6311                   418.542113              7  ...                 0
# 6727                   390.622196             10  ...                 0
# 7218                   389.933307             15  ...                 0
# 7695                   330.911089             79  ...                 0
# 9783                   389.211085             10  ...                 2
# 9968                   383.422197             35  ...                 0
# 11230                  135.429908             69  ...                 0
# 15275                  418.411083             10  ...                 0
# 17402                  271.181268             66  ...                 1
# 17571                  315.133312              1  ...                 0
#
#        team1_p6_networth  team1_p6_damage  team1_p6_creeps  team1_p6_level  \
# 4465                3379              552                3               2
# 5204                4831              265                1               2
# 6311                6767             1017                6               6
# 6727                8528             2142               11               9
# 7218                3136              150                0               1
# 7695                2245                0                0               1
# 9783                4328              661                8               5
# 9968                3664                0                0               1
# 11230               3873              376                6               4
# 15275               5160             1112                6               7
# 17402               7178             2111               15               6
# 17571               1247                7                0               1
#
#        team1_p6_objective_damage  team1_p6_denies  team1_p6_gold_per_minute  \
# 4465                           0                0                225.266652
# 5204                           0                1                334.325236
# 6311                           0                1                462.437326
# 6727                           0                2                568.533295
# 7218                           0                0                209.066653
# 7695                           0                0                149.666657
# 9783                           0                0                288.533314
# 9968                           0                0                244.266650
# 11230                          0                1                273.710228
# 15275                          0                0                343.999977
# 17402                          0                0                503.719263
# 17571                          0                0                 83.133328
#
#        team1_p6_player_healing  team1_p6_self_healing
# 4465                         0                      0
# 5204                        80                     80
# 6311                         0                      0
# 6727                       365                    365
# 7218                         0                      0
# 7695                         0                      0
# 9783                         0                      0
# 9968                         0                      0
# 11230                        0                      0
# 15275                        0                      0
# 17402                       90                     90
# 17571                        0                      0
#
# [12 rows x 184 columns]

# %% [markdown]
# # Inspecting Correlations

# %%
corr = df.corr(numeric_only=True)

print(corr["team0_won"].sort_values(ascending=False))
# Out:
# team0_won                     1.000000
# team0_team_gold_per_minute    0.308055
# team0_team_total_networth     0.307875
# team0_team_avg_level          0.292020
# team0_team_total_kills        0.290339
#                                 ...
# team1_team_avg_level         -0.270500
# team0_team_total_deaths      -0.277919
# team1_team_total_kills       -0.282978
# team1_team_total_networth    -0.287008
# team1_team_gold_per_minute   -0.287288
# Name: team0_won, Length: 184, dtype: float64
